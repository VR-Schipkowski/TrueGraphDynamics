# %% [markdown]
# --------------------------------------------
# # follows.tsv file structure
# --------------------------------------------
# id|time_scraped|follower|followed
# id - unique integer id
# time_scraped - datetime of when the edge was added to the data
# follower - int foreign key referencing the follower user
# followed - int foreign key referencing the followed user

# %%
#load follows.tsv
from helper.load_tsv import load_tsv
df_follows = load_tsv("../../Data/OriginalData/follows.tsv")
print(f"Follows dataframe size: {df_follows.shape}")
# Out:
# 📄 File: ../../Data/OriginalData/follows.tsv
# ------------------------------------------------------------
# Rows: 4,002,115
# Columns: 4
#
# 📌 Data types:
# id               int64
# time_scraped    object
# follower         int64
# followed         int64
# dtype: object
#
# No missing values.
#
# 🧠 Memory usage:
# 377.42768478393555 mega_bytes
#
# 👀 Head:
#         id                time_scraped  follower  followed
# 0  2701620     2022-11-03 18:55:20.902     12475     22025
# 1  2701622  2022-11-03 18:55:22.675183     12475     22026
# 2  2701624  2022-11-03 18:55:23.910835     12475     22027
# 3  2701626  2022-11-03 18:55:25.455047     12475     22028
# 4  2701628  2022-11-03 18:55:27.146986     12475     17280
# Follows dataframe size: (4002115, 4)

# %%
#save cleaned dataframe
df_follows.to_csv("../../Data/ProcessedData/follows_cleaned.tsv", sep="\t", index=False)
from helper.load_tsv import save_tsv
save_tsv(df_follows, "../../Data/ProcessedData/follows_cleaned.tsv")
# Out:
# ✅ DataFrame saved to ../../Data/ProcessedData/follows_cleaned.tsv
